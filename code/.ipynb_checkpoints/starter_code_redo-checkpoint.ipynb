# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Standardised tests, by its very name, should be a standard made available to the whole student body. The tests should ideally be a fair representation of the capabilities of all high school students. However, the data shows that not all states have good participation rates, in particular, Oregon.
#
# We would like to explore ways in which Oregon can improve in this area.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ## Data Sets used:
#
# act_2017.csv<br>
# act_2018.csv<br>
# act_2019.csv<br>
# sat_2017.csv<br>
# sat_2018.csv<br>
# sat_2019.csv<br>

# %% [markdown]
# ### Outside Research

# %% [markdown]
# https://www.census.gov/data/tables/2017/econ/school-finances/secondary-education-finance.html<br>
# https://www.census.gov/data/tables/2018/econ/school-finances/secondary-education-finance.html<br>
# https://www.census.gov/data/tables/2019/econ/school-finances/secondary-education-finance.html<br>
# https://www.census.gov/programs-surveys/school-finances/data/tables.html<br>
# https://collegereadiness.collegeboard.org/sat/k12-educators/sat-school-day/about#:~:text=SAT%20School%20Day%20provides%20schools,widely%20accepted%20at%20U.S.%20colleges<br>
# http://www.higheredinfo.org/dbrowser/index.php?submeasure=63&year=2018&level=nation&mode=graph&state=<br>
# https://www.edweek.org/teaching-learning/sat-scores-see-slight-increase-as-test-taking-surges/2018/10<br>
# https://educationdata.org/public-education-spending-statistics<br>
# https://www.opb.org/news/article/oregon-standardized-test-scores-racial-gaps-2017/https://data.ed.gov/dataset/college-scorecard-all-data-files-through-6-2020/resources<br>
# https://www.governing.com/archive/state-education-spending-per-pupil-data.html<br>
# https://www.osba.org/Resources/Article/Budget_and_Finance/Comprehensive_Analysis_of_K-12_Education_Finance_in_Oregon.aspx<br>
# https://reports.collegeboard.org/archive/sat-suite-program-results/2017/class-2017-results<br>
# https://www.oregon.gov/ode/reports-and-data/taskcomm/Documents/QEMReports/QEC%20Short%20Paper%20Final%205-22-18%20v2.pdf<br>
# https://www.kaptest.com/act/act-test-dates<br>
# https://www.americashealthrankings.org/explore/annual/measure/Graduation/<br>
# https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html - replacing ACT with SAT<br>
# https://www.oregonlive.com/education/2019/09/oregon-schools-deliver-worst-test-scores-in-5-years.html<br>
# https://www.businessgrants.org/2019/01/key-difference-between-federal-state-grants.html?m=1<br>
# https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice <br>
# https://www.collegeraptor.com/getting-in/articles/act-sat/states-act-sat-given-free/<br>
# https://www.publicschoolreview.com/blog/an-overview-of-the-funding-of-public-schools<br>

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
numberlist = [1,1,10,19,19]

def AverageNums(numbers):
    x = 0
    for num in numbers:
        x += num
    return x/len(numbers)

AverageNums(numberlist)
# Out:
# 10.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
###### Code:

def SD(numbers):
    TotalCount = 0
    for num in numbers:
        TotalCount += (num - AverageNums(numbers))**2
    return pow((TotalCount / len(numbers)),0.5)

SD(numberlist)
# Out:
# 8.049844718999243

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def convert_to_decimal(x):
    return float(x.strip('%'))/100

# function to covert to decimal

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ## SAT 2017 Clean up

# %%
def convert_to_decimal(x):
    return float(x.strip('%'))/100

# function to covert to decimal

def sat_score_to_percentage(x):
    return round(float(x/1600),2)

# function to convert SAT score to percentage

def act_score_to_percentage(x):
    return round(float(x/36),2)

# function to convert ACT score to percentage

def convert_dollar_to_decimal(x):
    y = x.replace('$', '')
    z = y.replace(',', '')
    return int(z)

# function to turn Income object in Median_income dataset into int

def strip_plus_minus(x):
    y = x.replace('+/- $', '')
    z = y.replace(',','')
    return int(z)

def convert_to_float(x):
    return float(x)

# function to return string into float
    
# function to turn Margin of Error object in Median_income dataset into int

# %%
sat_2017 = pd.read_csv('../data/sat_2017.csv')
sat_2017.rename(columns={
    'Evidence-Based Reading and Writing': 'EBRW',
}, inplace = True)

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   EBRW           51 non-null     int64
#  3   Math           51 non-null     int64
#  4   Total          51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2017['Participation'] = sat_2017['Participation'].apply(lambda x: convert_to_decimal(x))
sat_2017['Total'] = sat_2017['Total'].apply(lambda x: sat_score_to_percentage(x))

# convert total and participation into percentage

# %%
sat_2017.sort_values('Math').head()
sat_2017['Math'].replace(52, 524, inplace = True)
## replace the wrong value with the correct value

# %% [markdown]
# ## SAT 2018 Cleanup

# %%
sat_2018 = pd.read_csv('../data/sat_2018.csv')
sat_2018.rename(columns={
    'Evidence-Based Reading and Writing': 'EBRW',
}, inplace = True)

sat_2018['Participation'] = sat_2018['Participation'].apply(lambda x: convert_to_decimal(x))
sat_2018['Total'] = sat_2018['Total'].apply(lambda x: sat_score_to_percentage(x))

# %% [markdown]
# ## SAT 2019 Cleanup

# %%
sat_2019 = pd.read_csv('../data/sat_2019.csv')
sat_2019.rename(columns={
    'Participation Rate': 'Participation',
}, inplace = True)

#renamed column Participation Rate to match other data sets

sat_2019.drop(47, axis = 0, inplace = True,errors='ignore')
sat_2019.drop(39, axis = 0, inplace = True,errors='ignore')

## remove virgin islands and puerto rico from state list, as they are not states of America

sat_2019['Participation'] = sat_2019['Participation'].apply(lambda x: convert_to_decimal(x))
sat_2019['Total'] = sat_2019['Total'].apply(lambda x: sat_score_to_percentage(x))
   
## convert Participation to float

# %% [markdown]
# ## ACT 2017 Cleanup

# %%
act_2017 = pd.read_csv('../data/act_2017.csv')

act_2017.drop(0, axis = 0, inplace = True)

# removed national results from dataset

act_2017['Science'].replace(2.3, 23.2, inplace = True)

# replaced maryland science score to 23.2

act_2017['Participation'] = act_2017['Participation'].apply(lambda x: convert_to_decimal(x))

#convert participation into decimal

act_2017['Composite'].replace('20.2x', 20.2, inplace = True)

# replace wrong score with correct score Wyoming Composite Score
# https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf

act_2017.rename(columns={
    'Composite' : 'Total'
}, inplace = True)

# %%
act_2017['Total'] = act_2017['Total'].apply( lambda x : convert_to_float(x))
act_2017['Total'] = act_2017['Total'].apply(lambda x: act_score_to_percentage(x))
# convert composite into float and %

act_2017_dropped = act_2017.drop(['English', 'Math', 'Reading', 'Science'], axis = 1)

# drop Eng Math Science Reading columns from act 2017

# %% [markdown]
# ## ACT 2018 Cleanup

# %%
act_2018 = pd.read_csv('../data/act_2018.csv')

act_2018.drop_duplicates(keep = 'first', inplace = True, ignore_index = True)

# dropped duplicate entry

act_2018[act_2018['State'] == 'District of columbia']
act_2018['State'].replace('District of columbia','District of Columbia',inplace=True)
act_2018.rename(columns={
    'Composite' : 'Total'
}, inplace = True)

# renamed District of columbia to District of Columbia

act_2018['Participation'] = act_2018['Participation'].apply( lambda x: convert_to_decimal(x))
act_2018['Total'] = act_2018['Total'].apply(lambda x: act_score_to_percentage(x))

# convert Participation from object to float
# convert Composite into %

# %% [markdown]
# ## ACT 2019 cleanup

# %%
act_2019 = pd.read_csv('../data/act_2019.csv')

# %%
act_2019.drop(51, axis = 0, inplace = True)

# remove National

# %%
act_2019.rename(columns={
    'Composite' : 'Total'
}, inplace = True)

# %%
act_2019['Participation'] = act_2019['Participation'].apply( lambda x : convert_to_decimal(x))
act_2019['Total'] = act_2019['Total'].apply(lambda x: act_score_to_percentage(x))
# convert Participation to float
# convert composite to %

# %% [markdown]
# ## Merge Datasets

# %%
merge1 = pd.merge(left = act_2017_dropped,
         right = act_2018,
         on = 'State',
         how = 'right',
         suffixes = ('_2017', '_2018')
        )
act_merge = pd.merge(left = merge1,
                  right = act_2019,
                  on = 'State',
                  how = 'right',
                  suffixes = ('_2019', '_2019')
                 ).rename(columns = {'Participation' : 'Participation_2019',
                                     'Total' : 'Total_2019'})

act_merge = act_merge[['State', 
                       'Participation_2017', 
                       'Participation_2018', 
                       'Participation_2019',
                       'Total_2017',
                       'Total_2018',
                       'Total_2019']]
act_merge

# merged 3 ACT datasets on state with participation and total
# Out:
#                    State  Participation_2017  Participation_2018  \
# 0                Alabama                1.00                1.00
# 1                 Alaska                0.65                0.33
# 2                Arizona                0.62                0.66
# 3               Arkansas                1.00                1.00
# 4             California                0.31                0.27
# 5               Colorado                1.00                0.30
# 6            Connecticut                0.31                0.26
# 7               Delaware                0.18                0.17
# 8   District of Columbia                0.32                0.32
# 9                Florida                0.73                0.66
# 10               Georgia                0.55                0.53
# 11                Hawaii                0.90                0.89
# 12                 Idaho                0.38                0.36
# ...

# %%
sat_2017_dropped = sat_2017.drop(['EBRW','Math'], axis = 1)
sat_2018_dropped = sat_2018.drop(['EBRW','Math'], axis = 1)
sat_2019_dropped = sat_2019.drop(['EBRW','Math'], axis = 1)

merge3 = pd.merge(left = sat_2017_dropped,
         right= sat_2018_dropped,
         on = 'State',
         how = 'inner',
         suffixes = ('_2017', '_2018')
        )

sat_merge = pd.merge(left = merge3,
             right = sat_2019_dropped,
             on = 'State',
             how = 'inner',
             suffixes = ('_2018', '_2019')
            ).rename(columns = {'Participation' : 'Participation_2019',
                                                            'Total' : 'Total_2019'})
                    
sat_merge = sat_merge[['State', 'Participation_2017', 'Participation_2018', 'Participation_2019', 'Total_2017', 'Total_2018', 'Total_2019']]
sat_merge

# merged 3 SAT datasets on state with participation and total
# Out:
#                    State  Participation_2017  Participation_2018  \
# 0                Alabama                0.05                0.06
# 1                 Alaska                0.38                0.43
# 2                Arizona                0.30                0.29
# 3               Arkansas                0.03                0.05
# 4             California                0.53                0.60
# 5               Colorado                0.11                1.00
# 6            Connecticut                1.00                1.00
# 7               Delaware                1.00                1.00
# 8   District of Columbia                1.00                0.92
# 9                Florida                0.83                0.56
# 10               Georgia                0.61                0.70
# 11                Hawaii                0.55                0.56
# 12                 Idaho                0.93                1.00
# ...

# %%
# add Test and Year column for ACT

act_2017_dropped['Test'] = 'ACT'
act_2017_dropped['Year'] = 2017
# act_2017_dropped = act_2017_dropped.rename(columns = {'Composite' : 'Total'})
act_2018['Test'] = 'ACT'
act_2018['Year'] = 2018
# act_2018 = act_2018.rename(columns = {'Composite' : 'Total'})
act_2019['Test'] = 'ACT'
act_2019['Year'] = 2019
# act_2019 = act_2019.rename(columns = {'Composite' : 'Total'})
act_2019

# drop unused and add Test and Year column for SAT

sat_2017_dropped = sat_2017.drop(columns=['EBRW', 'Math'])
sat_2017_dropped['Test'] = 'SAT'
sat_2017_dropped['Year'] = 2017
sat_2018_dropped = sat_2018.drop(columns=['EBRW', 'Math'])
sat_2018_dropped['Test'] = 'SAT'
sat_2018_dropped['Year'] = 2018
sat_2019_dropped = sat_2019.drop(columns=['EBRW', 'Math'])
sat_2019_dropped['Test'] = 'SAT'
sat_2019_dropped['Year'] = 2019
sat_2019_dropped

all_merged_concat = pd.concat(objs = [act_2017_dropped, act_2018, act_2019, sat_2017_dropped, sat_2018_dropped, sat_2019_dropped], axis = 0)

# %%
all_merged_concat
# Out:
#             State  Participation  Total Test  Year
# 1         Alabama           1.00   0.53  ACT  2017
# 2          Alaska           0.65   0.55  ACT  2017
# 3         Arizona           0.62   0.55  ACT  2017
# 4        Arkansas           1.00   0.54  ACT  2017
# 5      California           0.31   0.63  ACT  2017
# ..            ...            ...    ...  ...   ...
# 48       Virginia           0.68   0.70  SAT  2019
# 49     Washington           0.70   0.67  SAT  2019
# 50  West Virginia           0.99   0.59  SAT  2019
# 51      Wisconsin           0.03   0.80  SAT  2019
# 52        Wyoming           0.03   0.77  SAT  2019
#
# [306 rows x 5 columns]

# %%
# import median income data
median_income = pd.read_csv('../data/Median_Income.csv')

# %%
median_income.info()
median_income['Median Household Income by State'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 3 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Median Household Income by State  54 non-null     object
#  1   Unnamed: 1                        53 non-null     object
#  2   Unnamed: 2                        53 non-null     object
# dtypes: object(3)
# memory usage: 1.4+ KB
# array(['State', 'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
# ...

# %%
median_income.head()
# Out:
#   Median Household Income by State Unnamed: 1       Unnamed: 2
# 0                            State     Income  Margin Of Error
# 1                          Alabama    $50,536         +/- $304
# 2                           Alaska    $77,640       +/- $1,015
# 3                          Arizona    $58,945         +/- $266
# 4                         Arkansas    $47,597         +/- $328

# %%
median_income.drop(index=0, inplace = True)
median_income.drop(index=52, inplace = True)
median_income.drop(index=53, inplace = True)
median_income.reset_index(drop = True, inplace = True)

# %%
median_income = median_income.rename(columns={
    'Median Household Income by State' : 'State',
    'Unnamed: 1' : 'Income',
    'Unnamed: 2' : 'Margin Of Error'}
                            )

# %%
median_income['Income'] = median_income['Income'].apply(lambda x: convert_dollar_to_decimal(x))
median_income['Margin Of Error'] = median_income['Margin Of Error'].apply(lambda x: strip_plus_minus(x))

# %%
median_income.drop('Margin Of Error', axis = 1, inplace = True)

# %%
k12_and_post = pd.read_csv('../data/k12_and_post_spending.csv')

# %%
k12_and_post.shape
# Out:
# (52, 3)

# %%
k12_and_post.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   51 non-null     object
#  1   K-12 Spending           51 non-null     object
#  2   Postsecondary Spending  51 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
k12_and_post['State'].unique()
# Out:
# array(['New York', 'Vermont', 'District of Columbia', 'Connecticut',
#        'New Jersey', 'Alaska', 'Pennsylvania', 'Massachusetts', 'Hawaii',
#        'Delaware', 'Wyoming', 'Illinois', 'New Hampshire', 'Michigan',
#        'Rhode Island', 'Oregon', 'Iowa', 'Maryland', 'Washington',
#        'North Dakota', 'California', 'New Mexico', 'Nebraska', 'Virginia',
#        'Maine', 'Ohio', 'Kentucky', 'Alabama', 'Minnesota', 'Wisconsin',
#        'Colorado', 'Arkansas', 'Montana', 'West Virginia', 'Mississippi',
#        'Kansas', 'South Carolina', 'Louisiana', 'Utah', 'Missouri',
#        'Indiana', 'North Carolina', 'Texas', 'Georgia', 'South Dakota',
#        'Oklahoma', 'Tennessee', 'Florida', 'Arizona', 'Nevada', 'Idaho',
#        nan], dtype=object)

# %%
k12_and_post[k12_and_post['State'].isnull()]
# Out:
#    State K-12 Spending Postsecondary Spending
# 51   NaN           NaN                    NaN

# %%
k12_and_post.drop(51, axis = 0, inplace = True)

# %%
k12_and_post.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   51 non-null     object
#  1   K-12 Spending           51 non-null     object
#  2   Postsecondary Spending  51 non-null     object
# dtypes: object(3)
# memory usage: 1.6+ KB

# %%
k12_and_post['K-12 Spending'] = k12_and_post['K-12 Spending'].apply(lambda x : convert_dollar_to_decimal(x))

# %%
k12_and_post['Postsecondary Spending'] = k12_and_post['Postsecondary Spending'].apply(lambda x : convert_dollar_to_decimal(x))

# %%
k12_and_post.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   51 non-null     object
#  1   K-12 Spending           51 non-null     int64
#  2   Postsecondary Spending  51 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.6+ KB

# %%
public_edu_funding = pd.read_csv('../data/public_education_funding.csv')

# %%
public_edu_funding.shape
# Out:
# (52, 3)

# %%
public_edu_funding.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State                  51 non-null     object
#  1   Federal Funding        51 non-null     object
#  2   State & Local Funding  51 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
public_edu_funding.head()
# Out:
#                   State Federal Funding State & Local Funding
# 0                Alaska          $3,064               $16,252
# 1  District of Columbia          $2,354               $26,468
# 2          South Dakota          $1,649               $10,262
# 3               Montana          $1,646               $11,316
# 4             Louisiana          $1,621               $11,211

# %%
public_edu_funding['State'].unique()
# Out:
# array(['Alaska', 'District of Columbia', 'South Dakota', 'Montana',
#        'Louisiana', 'New Mexico', 'North Dakota', 'Hawaii',
#        'West Virginia', 'Mississippi', 'Kentucky', 'Delaware', 'Vermont',
#        'Pennsylvania', 'Rhode Island', 'Arkansas', 'Wyoming', 'Texas',
#        'California', 'Florida', 'Alabama', 'South Carolina', 'Illinois',
#        'Michigan', 'Arizona', 'Tennessee', 'New York', 'Ohio', 'Georgia',
#        'Maine', 'North Carolina', 'Nebraska', 'Kansas', 'Missouri',
#        'Oklahoma', 'Iowa', 'Indiana', 'Wisconsin', 'Oregon',
#        'New Hampshire', 'Maryland', 'Washington', 'Connecticut',
#        'Massachusetts', 'New Jersey', 'Nevada', 'Virginia', 'Idaho',
#        'Minnesota', 'Colorado', 'Utah', nan], dtype=object)

# %%
public_edu_funding[public_edu_funding['State'].isnull()]
# Out:
#    State Federal Funding State & Local Funding
# 51   NaN             NaN                   NaN

# %%
public_edu_funding.drop(51, axis=0, inplace = True)

# %%
public_edu_funding.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State                  51 non-null     object
#  1   Federal Funding        51 non-null     object
#  2   State & Local Funding  51 non-null     object
# dtypes: object(3)
# memory usage: 1.6+ KB

# %%
public_edu_funding['Federal Funding'] = public_edu_funding['Federal Funding'].apply( lambda x: convert_dollar_to_decimal(x))

# %%
public_edu_funding['State & Local Funding'] = public_edu_funding['State & Local Funding'].apply( lambda x: convert_dollar_to_decimal(x))

# %%
public_edu_funding.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State                  51 non-null     object
#  1   Federal Funding        51 non-null     int64
#  2   State & Local Funding  51 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.6+ KB

# %%
# # normal merged datasets
# merge1 = pd.merge(left = act_2017_dropped,
#          right = act_2018,
#          on = 'State',
#          how = 'right',
#          suffixes = ('_2017', '_2018')
#         )
all_merged = pd.merge(left = act_merge,
                      right = sat_merge,
                      on = 'State',
                      suffixes = ('_ACT', '_SAT')
                     )
all_merged = pd.merge(left = all_merged,
                      right = median_income,
                      on = 'State'
                     )
all_merged = pd.merge(left = all_merged,
                      right = k12_and_post,
                      on = 'State'
                     )
all_merged = pd.merge(left = all_merged,
                      right = public_edu_funding,
                      on = 'State'
                     )

all_merged
# Out:
#                    State  Participation_2017_ACT  Participation_2018_ACT  \
# 0                Alabama                    1.00                    1.00
# 1                 Alaska                    0.65                    0.33
# 2                Arizona                    0.62                    0.66
# 3               Arkansas                    1.00                    1.00
# 4             California                    0.31                    0.27
# 5               Colorado                    1.00                    0.30
# 6            Connecticut                    0.31                    0.26
# 7               Delaware                    0.18                    0.17
# 8   District of Columbia                    0.32                    0.32
# 9                Florida                    0.73                    0.66
# 10               Georgia                    0.55                    0.53
# 11                Hawaii                    0.90                    0.89
# ...

# %%
all_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   51 non-null     object
#  1   Participation_2017_ACT  51 non-null     float64
#  2   Participation_2018_ACT  51 non-null     float64
#  3   Participation_2019_ACT  51 non-null     float64
#  4   Total_2017_ACT          51 non-null     float64
#  5   Total_2018_ACT          51 non-null     float64
#  6   Total_2019_ACT          51 non-null     float64
#  7   Participation_2017_SAT  51 non-null     float64
#  8   Participation_2018_SAT  51 non-null     float64
#  9   Participation_2019_SAT  51 non-null     float64
#  10  Total_2017_SAT          51 non-null     float64
#  11  Total_2018_SAT          51 non-null     float64
#  12  Total_2019_SAT          51 non-null     float64
#  13  Income                  51 non-null     int64
# ...

# %% [markdown]
# ### Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**State**|*Object*|all_merged|State data applies to.| <br>
# |**Participation_2017_ACT**|*float64*|all_merged|Participation rate in 2017 (in percent).| <br>
# |**Participation_2018_ACT**|*float64*|all_merged|Participation rate in 2018 (in percent).| <br>
# |**Participation_2019_ACT**|*float64*|all_merged|Participation rate in 2019 (in percent).| <br>
# |**Total_2017_ACT**|*float64*|all_merged|Percentage of total score over total possible score for ACT 2017.|  <br>
# |**Total_2018_ACT**|*float64*|all_merged|Percentage of total score over total possible score for ACT 2018.|  <br>
# |**Total_2019_ACT**|*float64*|all_merged|Percentage of total score over total possible score for ACT 2019.|  <br>
# |**Participation_2017_SAT**|*float64*|all_merged|Participation rate in 2017 (in percent).|  <br>
# |**Participation_2018_SAT**|*float64*|all_merged|Participation rate in 2018 (in percent).|   <br>
# |**Participation_2019_SAT**|*float64*|all_merged|Participation rate in 2019 (in percent).|  <br>
# |**Total_2017_SAT**|*float64*|all_merged|Percentage of total score over total possible score for SAT 2017.|  <br>
# |**Total_2018_SAT**|*float64*|all_merged|Percentage of total score over total possible score for SAT 2018.|  <br>
# |**Total_2019_SAT**|*float64*|all_merged|Percentage of total score over total possible score for SAT 2019.|  <br>
# |**Income**|*int64*|all_merged|Median Household income by state.| <br>
# |**K12 Spending**|*int64*|all_merged|Amount spent on K12 Education.| <br>
# |**Postsecondary Spending**|*int64*|all_merged|Amount spent on Postsecondary Education.| <br>
# |**Federal Funding**|*int64*|all_merged|Amount of Federal funding.| <br>
# |**State and Local funding**|*Object*|all_merged|Amount of state and local funding.| <br>
# |**ACT_ave_par**|*Object*|all_merged|Average of ACT participations for State| <br>
# |**SAT_ave_par**|*Object*|all_merged|Average of SAT participations for State| <br>
# |**State**|*Object*|all_merged_concat|State data applies to.| <br>
# |**Participation**|*float64*|all_merged_concat|Participation rate for specified test and year.| <br>
# |**Total**|*float64*|all_merged_concat|Percentage of total score over total possible score for specified test and year.| <br>
# |**Test**|*Object*|all_merged_concat|Test that was taken|The year the test was taken.| <br>
# |**State**|*Object*|all_merged_concat|State data applies to.| <br>
# |**Income**|*Object*|all_merged_concat|State data applies to.| <br>
# |**Margin of Error**|*Object*|all_merged_concat|State data applies to.| <br>

# %%
all_merged
# Out:
#                    State  Participation_2017_ACT  Participation_2018_ACT  \
# 0                Alabama                    1.00                    1.00
# 1                 Alaska                    0.65                    0.33
# 2                Arizona                    0.62                    0.66
# 3               Arkansas                    1.00                    1.00
# 4             California                    0.31                    0.27
# 5               Colorado                    1.00                    0.30
# 6            Connecticut                    0.31                    0.26
# 7               Delaware                    0.18                    0.17
# 8   District of Columbia                    0.32                    0.32
# 9                Florida                    0.73                    0.66
# 10               Georgia                    0.55                    0.53
# 11                Hawaii                    0.90                    0.89
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# Create New Dict for ACT Standard Deviations
act_merge_dict = {}

# create a dict to check for numberical values for function SD

for column in act_merge.columns.values:
    try:
        act_merge_dict[column] = (SD(act_merge[column]))
    except:
        continue
act_merge_dict
# Out:
# {'Participation_2017': 0.3182417575123181,
#  'Participation_2018': 0.33701735820410317,
#  'Participation_2019': 0.3417582373703047,
#  'Total_2017': 0.056151741468747754,
#  'Total_2018': 0.058096156488125876,
#  'Total_2019': 0.06067669156813001}

# %%
act_SD = {x: SD(act_merge[x]) for x in act_merge if x in list(act_merge_dict.keys())}
act_SD
# Out:
# {'Participation_2017': 0.3182417575123181,
#  'Participation_2018': 0.33701735820410317,
#  'Participation_2019': 0.3417582373703047,
#  'Total_2017': 0.056151741468747754,
#  'Total_2018': 0.058096156488125876,
#  'Total_2019': 0.06067669156813001}

# %%
#create new dict for SAT Standard Deviations
sat_merge_dict = {}

# create a dict to check for numerical values for function SD
for column in sat_merge.columns.values:
    try:
        sat_merge_dict[column] = (SD(sat_merge[column]))
    except:
        continue

# %%
#dict comprehension to get SD for all numerical values
sat_SD = {x: SD(sat_merge[x]) for x in sat_merge if x in list(sat_merge_dict.keys())}
sat_SD
# Out:
# {'Participation_2017': 0.3492907076664507,
#  'Participation_2018': 0.3694661922353942,
#  'Participation_2019': 0.3836584048685726,
#  'Total_2017': 0.05764505798848644,
#  'Total_2018': 0.05847609816097734,
#  'Total_2019': 0.06004291685675703}

# %%
# create dict for all_merged dataframe Standard Deviations

all_merged_dict = {}

# %%
act_2019.head()
# Out:
#         State  Participation  Total Test  Year
# 0     Alabama           1.00   0.52  ACT  2019
# 1      Alaska           0.38   0.56  ACT  2019
# 2     Arizona           0.73   0.53  ACT  2019
# 3    Arkansas           1.00   0.54  ACT  2019
# 4  California           0.23   0.63  ACT  2019

# %% [markdown]
# ACT is comprised of 4 tests, English, Math, Reading and Science

# %%
sat_2019.head()
# Out:
#         State  Participation  EBRW  Math  Total
# 0     Alabama           0.07   583   560   0.71
# 1      Alaska           0.41   556   541   0.69
# 2     Arizona           0.31   569   565   0.71
# 3    Arkansas           0.06   582   559   0.71
# 4  California           0.63   534   531   0.67

# %% [markdown]
# SAT is comprised of 2 tests, Evidence Based Reading and Writing and Math.

# %%
all_merged.shape
# Out:
# (51, 18)

# %% [markdown]
# There are 51 states in the datasets

# %%
all_merged.describe()
# Out:
#        Participation_2017_ACT  Participation_2018_ACT  Participation_2019_ACT  \
# count               51.000000               51.000000               51.000000
# mean                 0.652549                0.617255                0.586667
# std                  0.321408                0.340371                0.345159
# min                  0.080000                0.070000                0.060000
# 25%                  0.310000                0.285000                0.245000
# 50%                  0.690000                0.660000                0.540000
# 75%                  1.000000                1.000000                1.000000
# max                  1.000000                1.000000                1.000000
#
#        Total_2017_ACT  Total_2018_ACT  Total_2019_ACT  Participation_2017_SAT  \
# count       51.000000       51.000000       51.000000               51.000000
# mean         0.598039        0.596667        0.596471                0.398039
# ...

# %%
all_merged_concat.groupby('Test')['Participation'].mean()
# Out:
# Test
# ACT    0.618824
# SAT    0.448693
# Name: Participation, dtype: float64

# %% [markdown]
# The average participation for ACT is 61%, and for SAT is 44%

# %%
all_merged_concat.groupby('Test')['Total'].mean()
# Out:
# Test
# ACT    0.597059
# SAT    0.700196
# Name: Total, dtype: float64

# %% [markdown]
# The average score in percentage for ACT is 59% and for SAT is 70%

# %%
all_merged_concat.loc[all_merged_concat['Test'] == 'ACT'].sort_values('Participation', ascending = True)
# Out:
#            State  Participation  Total Test  Year
# 19         Maine           0.06   0.68  ACT  2019
# 19         Maine           0.07   0.67  ACT  2018
# 20         Maine           0.08   0.68  ACT  2017
# 39  Rhode Island           0.12   0.69  ACT  2019
# 7       Delaware           0.13   0.67  ACT  2019
# ..           ...            ...    ...  ...   ...
# 24   Mississippi           1.00   0.52  ACT  2018
# 18     Louisiana           1.00   0.53  ACT  2018
# 17      Kentucky           1.00   0.56  ACT  2018
# 3       Arkansas           1.00   0.54  ACT  2019
# 50       Wyoming           1.00   0.55  ACT  2019
#
# [153 rows x 5 columns]

# %% [markdown]
# State with the lowest ACT participation is Maine, at 6%, 7% and 8% for 2017, 2018 and 2019 respectively.

# %%
all_merged_concat.loc[all_merged_concat['Test'] == 'SAT'].sort_values('Participation', ascending = True)
# Out:
#            State  Participation  Total Test  Year
# 34  North Dakota           0.02   0.80  SAT  2018
# 24   Mississippi           0.02   0.78  SAT  2017
# 15          Iowa           0.02   0.80  SAT  2017
# 34  North Dakota           0.02   0.79  SAT  2019
# 34  North Dakota           0.02   0.79  SAT  2017
# ..           ...            ...    ...  ...   ...
# 7       Delaware           1.00   0.62  SAT  2019
# 6    Connecticut           1.00   0.65  SAT  2019
# 5       Colorado           1.00   0.64  SAT  2019
# 12         Idaho           1.00   0.63  SAT  2018
# 5       Colorado           1.00   0.64  SAT  2018
#
# [153 rows x 5 columns]

# %% [markdown]
# State with the lowest SAT participation is North Dakota, at 2% for 2017, 2018 and 2019. Mississippi and Iowa also have low SAT participation rates.

# %%
all_merged[all_merged['State'] == 'Maine'].T
# Out:
#                            19
# State                   Maine
# Participation_2017_ACT   0.08
# Participation_2018_ACT   0.07
# Participation_2019_ACT   0.06
# Total_2017_ACT           0.68
# Total_2018_ACT           0.67
# Total_2019_ACT           0.68
# Participation_2017_SAT   0.95
# Participation_2018_SAT   0.99
# Participation_2019_SAT   0.99
# Total_2017_SAT           0.63
# Total_2018_SAT           0.63
# Total_2019_SAT           0.63
# Income                  57918
# K-12 Spending           15070
# Postsecondary Spending  18501
# Federal Funding          1061
# State & Local Funding   14960

# %% [markdown]
# Maine has very low ACT participation, but very high SAT participation rates of 95% and above.

# %%
all_merged[all_merged['State'] == 'North Dakota'].T
# Out:
#                                   34
# State                   North Dakota
# Participation_2017_ACT          0.98
# Participation_2018_ACT          0.98
# Participation_2019_ACT          0.96
# Total_2017_ACT                  0.56
# Total_2018_ACT                  0.56
# Total_2019_ACT                  0.55
# Participation_2017_SAT          0.02
# Participation_2018_SAT          0.02
# Participation_2019_SAT          0.02
# Total_2017_SAT                  0.79
# Total_2018_SAT                   0.8
# Total_2019_SAT                  0.79
# Income                         64894
# K-12 Spending                  13550
# Postsecondary Spending         25021
# Federal Funding                 1508
# State & Local Funding          14327

# %% [markdown]
# North Dakota has very high ACT participation rates of above 96%, but has the lowest SAT participation rates.

# %% [markdown]
# From the findings above, we can deduce that participation rate and score has a negative correlation. There also seems to be a trend between participation rates from a test to another.

# %%
# Establish size of figure.
plt.figure(figsize = (25,15))
sns.set(font_scale=1)
# Get correlation of variables. (statistical significance)
corr = all_merged.corr()

# Set up mask to be "True" in the upper triangle.
# because it will be the mirror image of lower triangle we'll see on our plot.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)

# %% [markdown]
# From the heatmap, not only can we see the negative correlation between test participation and score(-0.86), we also can see that there is also a negative correlation between ACT participation and SAT participation(-0.87).

# %% [markdown]
# Besides the above mentioned relationships, there are other noteworthy trends with participation.<br>
# There is a positive relation between income, k-12 spending, and state & local funding with SAT participation.

# %%
all_merged_ave_par = all_merged

# %%
# add new columns ACT_ave_par and SAT_ave_par for visualization

all_merged_ave_par['ACT_ave_par'] = round(((all_merged_ave_par['Participation_2017_ACT'] 
                                     + all_merged_ave_par['Participation_2018_ACT'] 
                                     + all_merged_ave_par['Participation_2019_ACT']) / 3) , 2)
all_merged_ave_par['SAT_ave_par'] = round(((all_merged_ave_par['Participation_2017_SAT'] 
                                     + all_merged_ave_par['Participation_2018_SAT'] 
                                     + all_merged_ave_par['Participation_2019_SAT']) / 3) , 2)

# %%
def StatesParBelow(x):
    return all_merged.loc[(all_merged['Participation_2017_ACT'] < x) & 
                   (all_merged['Participation_2018_ACT'] < x) &
                   (all_merged['Participation_2019_ACT'] < x) &
#                    (all_merged['Composite_2017'] < x) &  
#                    (all_merged['Composite_2018'] < x) &  
#                    (all_merged['Composite_2019'] < x) &
                   (all_merged['Participation_2017_SAT'] < x) & 
                   (all_merged['Participation_2018_SAT'] < x) &
                   (all_merged['Participation_2019_SAT'] < x) 
#                    (all_merged['Total_2017'] < x) &  
#                    (all_merged['Total_2018'] < x) &  
#                    (all_merged['Total_2019'] < x)
                  ]

# function to see which state has below x% participation rate.
# the first state to pop up at 60% is oregon

# %%
StatesParBelow(0.5)
# Out:
# Empty DataFrame
# Columns: [State, Participation_2017_ACT, Participation_2018_ACT, Participation_2019_ACT, Total_2017_ACT, Total_2018_ACT, Total_2019_ACT, Participation_2017_SAT, Participation_2018_SAT, Participation_2019_SAT, Total_2017_SAT, Total_2018_SAT, Total_2019_SAT, Income, K-12 Spending, Postsecondary Spending, Federal Funding, State & Local Funding, ACT_ave_par, SAT_ave_par]
# Index: []

# %%
StatesParBelow(0.6).T
# Out:
#                             37
# State                   Oregon
# Participation_2017_ACT     0.4
# Participation_2018_ACT    0.42
# Participation_2019_ACT    0.42
# Total_2017_ACT            0.61
# Total_2018_ACT            0.59
# Total_2019_ACT            0.59
# Participation_2017_SAT    0.43
# Participation_2018_SAT    0.48
# Participation_2019_SAT    0.51
# Total_2017_SAT            0.69
# Total_2018_SAT             0.7
# Total_2019_SAT            0.69
# Income                   62818
# K-12 Spending            11340
# Postsecondary Spending   37675
# Federal Funding            948
# State & Local Funding    12981
# ACT_ave_par               0.41
# SAT_ave_par               0.47

# %%
all_merged_sorted_by_k12_funding = all_merged.sort_values(['K-12 Spending'], ascending = True)
all_merged_sorted_by_k12_funding.reset_index(drop = True, inplace = True)
all_merged_sorted_by_k12_funding.loc[all_merged_sorted_by_k12_funding['State'] == 'Oregon'].T
# Out:
#                             21
# State                   Oregon
# Participation_2017_ACT     0.4
# Participation_2018_ACT    0.42
# Participation_2019_ACT    0.42
# Total_2017_ACT            0.61
# Total_2018_ACT            0.59
# Total_2019_ACT            0.59
# Participation_2017_SAT    0.43
# Participation_2018_SAT    0.48
# Participation_2019_SAT    0.51
# Total_2017_SAT            0.69
# Total_2018_SAT             0.7
# Total_2019_SAT            0.69
# Income                   62818
# K-12 Spending            11340
# Postsecondary Spending   37675
# Federal Funding            948
# State & Local Funding    12981
# ACT_ave_par               0.41
# SAT_ave_par               0.47

# %%
all_merged_sort_by_state_funding = all_merged.sort_values(['State & Local Funding'], ascending = True)
all_merged_sort_by_state_funding.reset_index(drop = True, inplace = True)
all_merged_sort_by_state_funding.loc[all_merged_sort_by_state_funding['State'] == 'Oregon'].T
# Out:
#                             27
# State                   Oregon
# Participation_2017_ACT     0.4
# Participation_2018_ACT    0.42
# Participation_2019_ACT    0.42
# Total_2017_ACT            0.61
# Total_2018_ACT            0.59
# Total_2019_ACT            0.59
# Participation_2017_SAT    0.43
# Participation_2018_SAT    0.48
# Participation_2019_SAT    0.51
# Total_2017_SAT            0.69
# Total_2018_SAT             0.7
# Total_2019_SAT            0.69
# Income                   62818
# K-12 Spending            11340
# Postsecondary Spending   37675
# Federal Funding            948
# State & Local Funding    12981
# ACT_ave_par               0.41
# SAT_ave_par               0.47

# %%
all_merged.describe()
# Out:
#        Participation_2017_ACT  Participation_2018_ACT  Participation_2019_ACT  \
# count               51.000000               51.000000               51.000000
# mean                 0.652549                0.617255                0.586667
# std                  0.321408                0.340371                0.345159
# min                  0.080000                0.070000                0.060000
# 25%                  0.310000                0.285000                0.245000
# 50%                  0.690000                0.660000                0.540000
# 75%                  1.000000                1.000000                1.000000
# max                  1.000000                1.000000                1.000000
#
#        Total_2017_ACT  Total_2018_ACT  Total_2019_ACT  Participation_2017_SAT  \
# count       51.000000       51.000000       51.000000               51.000000
# mean         0.598039        0.596667        0.596471                0.398039
# ...

# %% [markdown]
# Oregon is ranked 22 from the bottom and 27 from the bottom for K-12 spending and State and Local funding respectively.
#
# K-12 spending is at $11,340 per student, below the national average of $12,953.
# State and Local funding is at $12,981 per student, below the national average of $13,641.

# %% [markdown]
# Oregon is ranked 28 in state funding with $12,981 spent per student, below the national average of $13,641.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# We would like to explore what ways Oregon has to improve their test participation and scores.
#
# From the heatmap, not only can we see the negative correlation between test participation and score(-0.86), we also can see that there is also a negative correlation between ACT participation and SAT participation(-0.87).
#
# Besides the above mentioned relationships, there are other noteworthy trends with participation.
# There is a positive relation between income, k-12 spending, and state & local funding with SAT participation.

# %%
# Code
plt.figure(figsize = (16,9))
sns.set_theme(style='white')
sns.set(font_scale = 1.8)
sns.scatterplot(data=all_merged_concat, x='Participation', y='Total', hue='Test').set(title='Participation vs Average Score %')
plt.show()

# %% [markdown]
# This scatter plot shows that there is a negative correlation between participation and average score. The higher the participation rate, the lower the average score. (-0.86)

# %%
# Code
#visual
plt.figure(figsize = (16,9))
sns.set_theme(style='white')
sns.set(font_scale = 1.8)
sns.regplot(data=all_merged_ave_par, x='ACT_ave_par', y='SAT_ave_par').set(title='SAT Participation vs ACT Participation')
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between ACT and SAT participation rates. They are negatively correlated.

# %% [markdown]
# After more research, we found that there some states that mandate either SAT or ACT, and some states that offer free tests. This means that for the states that mandate and offer free tests, anyone can take the test without consequence. This may result in high participation and low score. (-0.86)
#
# On the other hand, students who opt to take test a instead of the state sponsored test b, either feels more confident in the test a, or has a preferred school. This type of student exhibits drive, which may result in good grades. This may be one of the scenarios that result in low participation but high average grades.
#
# Also, if one of the tests is sponsored by the state, it encourages students to take that test instead of the other, resulting in a negative correlation between SAT and ACT participation rates.

# %%
maine_2017_sat_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2017)]['Participation']
maine_2018_sat_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2018)]['Participation']
maine_2019_sat_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2019)]['Participation']
maine_2017_act_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2017)]['Participation']
maine_2018_act_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2018)]['Participation']
maine_2019_act_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2019)]['Participation']
maine_2017_sat_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2017)]['Total']
maine_2018_sat_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2018)]['Total']
maine_2019_sat_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2019)]['Total']
maine_2017_act_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2017)]['Total']
maine_2018_act_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2018)]['Total']
maine_2019_act_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Maine') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2019)]['Total']

## values for maine bar chart

# %%
plt.figure(figsize = (12, 8))
X = ['2017', '2018', '2019']
YMaine_sat_par = [maine_2017_sat_par.values[0],maine_2018_sat_par.values[0],maine_2019_sat_par.values[0]]
ZMaine_sat_score = [maine_2017_sat_score.values[0],maine_2018_sat_score.values[0],maine_2019_sat_score.values[0]]
  
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, YMaine_sat_par, 0.4, label = 'Par', color='cornflowerblue')
plt.bar(X_axis + 0.2, ZMaine_sat_score, 0.4, label = 'Score', color = 'coral')
plt.axhline(0.44, color='lightblue', label='National Average')
plt.axhline(0.70, color='lightsalmon', label='National Average')
plt.xticks(X_axis, X)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Participation in %", fontsize = 15)
plt.title("Maine SAT Participation and Score %",fontsize = 20)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize = (12, 8))
X = ['2017', '2018', '2019']
YMaine_act_par = [maine_2017_act_par.values[0],maine_2018_act_par.values[0],maine_2019_act_par.values[0]]
ZMaine_act_score = [maine_2017_act_score.values[0],maine_2018_act_score.values[0],maine_2019_act_score.values[0]]
  
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, YMaine_act_par, 0.4, label = 'Par', color='darkmagenta')
plt.bar(X_axis + 0.2, ZMaine_act_score, 0.4, label = 'Score', color = 'coral')
plt.axhline(0.61, color='orchid', label='National Average')
plt.axhline(0.59, color='lightsalmon', label='National Average')
plt.xticks(X_axis, X)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Participation in %", fontsize = 15)
plt.title("Maine ACT Participation and Score %", fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# These 2 charts are the participation rate vs score for Maine.
#
# Maines has the lowest ACT participation rate in the U.S, but has an above average score.
#
# It has a high participation rate for SAT, but a low average score.
#
# Maine is one of the states where ACT is compulsory for students, and are offered the test for free. This could explain the high participation and low score.
#
# It could also mean that students who still opted for SAT, which is not sponsored, are confident in their ability to score well. This results in lower participation but higher scores.

# %%
nd_2017_sat_par = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2017)]['Participation']
nd_2018_sat_par = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2018)]['Participation']
nd_2019_sat_par = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2019)]['Participation']
nd_2017_act_par = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2017)]['Participation']
nd_2018_act_par = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2018)]['Participation']
nd_2019_act_par = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2019)]['Participation']
nd_2017_sat_score = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2017)]['Total']
nd_2018_sat_score = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2018)]['Total']
nd_2019_sat_score = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2019)]['Total']
nd_2017_act_score = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2017)]['Total']
nd_2018_act_score = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2018)]['Total']
nd_2019_act_score = all_merged_concat.loc[(all_merged_concat['State'] == 'North Dakota') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2019)]['Total']

# %%
plt.figure(figsize = (12, 8))
X = ['2017', '2018', '2019']
Ynd_sat_par = [nd_2017_sat_par.values[0],nd_2018_sat_par.values[0],nd_2019_sat_par.values[0]]
Znd_sat_score = [nd_2017_sat_score.values[0],nd_2018_sat_score.values[0],nd_2019_sat_score.values[0]]
  
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, Ynd_sat_par, 0.4, label = 'Par', color='cornflowerblue')
plt.bar(X_axis + 0.2, Znd_sat_score, 0.4, label = 'Score', color = 'coral')
plt.axhline(0.44, color='lightblue', label='National Average')
plt.axhline(0.70, color='lightsalmon', label='National Average')
plt.xticks(X_axis, X)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Participation in %", fontsize = 15)
plt.title("North Dakota SAT Participation and Score %", fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize = (12, 8))
X = ['2017', '2018', '2019']
Ynd_act_par = [nd_2017_act_par.values[0],nd_2018_act_par.values[0],nd_2019_act_par.values[0]]
Znd_act_score = [nd_2017_act_score.values[0],nd_2018_act_score.values[0],nd_2019_act_score.values[0]]
  
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, Ynd_act_par, 0.4, label = 'Par', color='darkmagenta')
plt.bar(X_axis + 0.2, Znd_act_score, 0.4, label = 'Score', color = 'coral')
plt.axhline(0.61, color='orchid', label='National Average')
plt.axhline(0.59, color='lightsalmon', label='National Average')
plt.xticks(X_axis, X)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Participation in %", fontsize = 15)
plt.title("North Dakota ACT Participation and Score %", fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# On the other end of the spectrum, we can find North Dakota.
#
# North Dakota has the lowest SAT participation rate in the U.S, but has an above average score.
#
# It has a high participation rate for ACT, but a low average score.
#
# North Dakota is one of the states where ACT is compulsory for students, and are offered the test for free. This could explain the high participation and low score.
#
# Similar to Maine, the free tests and compulsory may be the reasons why the data is skewed.

# %%
# Code
fig, ax = plt.subplots(figsize=(16,9))
sns.set_theme(style='white')
sns.set(font_scale = 1.8)
sns.regplot(data=all_merged, x='Participation_2017_ACT', y='Income', ci = None, ax = ax, label = 'ACT_2017')
sns.regplot(data=all_merged, x='Participation_2018_ACT', y='Income', ci = None, ax = ax, label = 'ACT_2018')
sns.regplot(data=all_merged, x='Participation_2019_ACT', y='Income', ci = None, ax = ax, label = 'ACT_2019').set(title='ACT Participation vs Income by Year', xlabel = 'ACT Participation Rate')
# sns.regplot(data=all_merged, x='Participation_2017_SAT', y='Income', ci = None, ax = ax, label = '2017')
# sns.regplot(data=all_merged, x='Participation_2018_SAT', y='Income', ci = None, ax = ax, label = '2018')
# sns.regplot(data=all_merged, x='Participation_2019_SAT', y='Income', ci = None, ax = ax, label = '2019')
fig.legend(labels=['ACT_2017','ACT_2018','ACT_2019'])
plt.show()

# %% [markdown]
# ACT participation rate is negatively correlated to income. The higher the income, the lower ACT participation rate. (-0.51)

# %%
fig, ax = plt.subplots(figsize=(16,9))
sns.set_theme(style='white')
sns.set(font_scale = 1.8)
sns.regplot(data=all_merged, x='Participation_2017_SAT', y='Income', ci = None, ax = ax, label = '2017')
sns.regplot(data=all_merged, x='Participation_2018_SAT', y='Income', ci = None, ax = ax, label = '2018')
sns.regplot(data=all_merged, x='Participation_2019_SAT', y='Income', ci = None, ax = ax, label = '2019').set(title='SAT Participation vs Income by Year')
fig.legend(labels=['2017','2018','2019'])
plt.show()

# %% [markdown]
# SAT participation rate is positively correlated to income. The higher the income, the higher the participation rate. (0.47)

# %%
fig, ax = plt.subplots(figsize=(16,9))
sns.set_theme(style='white')
sns.set(font_scale = 1.8)
sns.regplot(data=all_merged, x='SAT_ave_par', y='Income').set(title='Average SAT Participation vs Income')
plt.show()

# %% [markdown]
# There is a positive correlation between income and SAT participation. (0.49).

# %%
fig, ax = plt.subplots(figsize=(16,9))
sns.set_theme(style='white')
sns.set(font_scale = 1.8)
sns.regplot(data=all_merged, x='SAT_ave_par', y='K-12 Spending').set(title='Average SAT Participation vs K - 12 Spending')
plt.show()

# %% [markdown]
# There is a positive correlation between K - 12 spending and SAT participation. (0.49).

# %%
fig, ax = plt.subplots(figsize=(16,9))
sns.set_theme(style='white')
sns.set(font_scale = 1.8)
sns.regplot(data=all_merged, x='SAT_ave_par', y='State & Local Funding').set(title='Average SAT Participation vs State & Local Funding')
plt.show()

# %% [markdown]
# There is a positive correlation between State & Local funding and SAT participation. (0.49).

# %%
oregon_2017_sat_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2017)]['Participation']
oregon_2018_sat_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2018)]['Participation']
oregon_2019_sat_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2019)]['Participation']
oregon_2017_act_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2017)]['Participation']
oregon_2018_act_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2018)]['Participation']
oregon_2019_act_par = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2019)]['Participation']
oregon_2017_sat_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2017)]['Total']
oregon_2018_sat_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2018)]['Total']
oregon_2019_sat_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2019)]['Total']
oregon_2017_act_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2017)]['Total']
oregon_2018_act_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2018)]['Total']
oregon_2019_act_score = all_merged_concat.loc[(all_merged_concat['State'] == 'Oregon') & (all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2019)]['Total']

# %%
plt.figure(figsize = (12, 8))
X = ['2017', '2018', '2019']
Yoregon_sat_par = [oregon_2017_sat_par.values[0],oregon_2018_sat_par.values[0],oregon_2019_sat_par.values[0]]
Zoregon_sat_score = [oregon_2017_sat_score.values[0],oregon_2018_sat_score.values[0],oregon_2019_sat_score.values[0]]
  
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, Yoregon_sat_par, 0.4, label = 'Par', color='cornflowerblue')
plt.bar(X_axis + 0.2, Zoregon_sat_score, 0.4, label = 'Score', color = 'coral')
plt.axhline(0.44, color='lightblue', label='National Average')
plt.axhline(0.70, color='lightsalmon', label='National Average')
plt.xticks(X_axis, X)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Participation in %", fontsize = 15)
plt.title("Oregon SAT Participation and Score %",fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# Oregon's SAT participation rate is about the same as the national average, with scores just shy of the national average.

# %%
plt.figure(figsize = (12, 8))
X = ['2017', '2018', '2019']
Yoregon_act_par = [oregon_2017_act_par.values[0],oregon_2018_act_par.values[0],oregon_2019_act_par.values[0]]
Zoregon_act_score = [oregon_2017_act_score.values[0],oregon_2018_act_score.values[0],oregon_2019_act_score.values[0]]
  
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, Yoregon_act_par, 0.4, label = 'Par', color='darkmagenta')
plt.bar(X_axis + 0.2, Zoregon_act_score, 0.4, label = 'Score', color = 'coral')
plt.axhline(0.61, color='orchid', label='National Average')
plt.axhline(0.59, color='lightsalmon', label='National Average')
plt.xticks(X_axis, X)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Participation in %", fontsize = 15)
plt.title("Oregon ACT Participation and Score %", fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# Oregon's ACT participation rates are below the national average and scores around the national average.

# %% [markdown]
# ### Comparing ACT and SAT Test subjects scores

# %%
act_eng_ave_2017 = round(((act_2017['English'].mean() / 36) * 100), 4)
sat_ebrw_ave_2017 = round(((sat_2017['EBRW'].mean() / 800) * 100) , 4)
act_math_ave_2017 = round(((act_2017['Math'].mean() / 36) * 100), 4)
sat_math_ave_2017 = round(((sat_2017['Math'].mean() / 800) * 100) , 4)
print(f'ACT English Ave 2017: {act_eng_ave_2017}%\n\
SAT English Ave 2017: {sat_ebrw_ave_2017}%\n\n\
ACT Math Ave 2017: {act_math_ave_2017}%\n\
SAT Math Ave 2017: {sat_math_ave_2017}%')
# Out:
# ACT English Ave 2017: 58.1427%
# SAT English Ave 2017: 71.1397%
#
# ACT Math Ave 2017: 58.8399%
# SAT Math Ave 2017: 69.6103%

# %% [markdown]
# ### Comparing ACT and SAT total scores over 3 years

# %%
act_2017_mean_score = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2017)]['Total'])
act_2018_mean_score = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2018)]['Total'])
act_2019_mean_score = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2019)]['Total'])
sat_2017_mean_score = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2017)]['Total'])
sat_2018_mean_score = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2018)]['Total'])
sat_2019_mean_score = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2019)]['Total'])

# %%
plt.figure(figsize = (12, 8))
X = ['2017', '2018', '2019']
Yact_mean_score = [act_2017_mean_score,act_2018_mean_score,act_2019_mean_score]
Zsat_mean_score = [sat_2017_mean_score,sat_2018_mean_score,sat_2019_mean_score]
  
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, Yact_mean_score, 0.4, label = 'ACT', color='darkmagenta')
plt.bar(X_axis + 0.2, Zsat_mean_score, 0.4, label = 'SAT', color = 'coral')
# plt.axhline(0.61, color='darkmagenta', label='National Average')
# plt.axhline(0.59, color='coral', label='National Average')
plt.xticks(X_axis, X)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Average Score in %", fontsize = 15)
plt.title("ACT and SAT average scores", fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# The average total scores of both tests overe 3 years did not show any significant change.

# %% [markdown]
# ### Comparing Participation rates between ACT and SAT over 3 years

# %%
act_2017_mean_par = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2017)]['Participation'])
act_2018_mean_par = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2018)]['Participation'])
act_2019_mean_par = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'ACT') & (all_merged_concat['Year'] == 2019)]['Participation'])
sat_2017_mean_par = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2017)]['Participation'])
sat_2018_mean_par = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2018)]['Participation'])
sat_2019_mean_par = AverageNums(all_merged_concat.loc[(all_merged_concat['Test'] == 'SAT') & (all_merged_concat['Year'] == 2019)]['Participation'])

# %%
plt.figure(figsize = (12, 8))
X = ['2017', '2018', '2019']
Yact_mean_par = [act_2017_mean_par,act_2018_mean_par,act_2019_mean_par]
Zsat_mean_par = [sat_2017_mean_par,sat_2018_mean_par,sat_2019_mean_par]
  
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, Yact_mean_par, 0.4, label = 'ACT', color='darkmagenta')
plt.bar(X_axis + 0.2, Zsat_mean_par, 0.4, label = 'SAT', color = 'coral')
# plt.axhline(0.61, color='darkmagenta', label='National Average')
# plt.axhline(0.59, color='coral', label='National Average')
plt.xticks(X_axis, X)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Participation in %", fontsize = 15)
plt.title("ACT and SAT average Participation in %", fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# The participation rate of ACT over 3 years show a steady decline. SAT on the other hand shows a steady increase. This may hint at a trend of students choosing SAT over ACT.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on the data, participation rates are heavily influenced by the state department of education's policies. This can see seen from states like Maine, North Dakota and Oregon.
#
# In Maine, as the state mandates SATs for all students and sponsors the test, almost all students attempted their SATs.
# In North Dakota, as the state mandates ACTs for all students and sponsors the test, almost all students attempted their ACTs.
# In Oregon, the states does not do either, resulting in lukewarm participation for the tests.
#
# Making one of the test free and compulsory is the most direct way to increase the participation rate, making the tests accessible to all students. There are records of states improving participation rates by doing so. This will create a more inclusive test environment, and to ensure that the tests are accessible to a wider range of students in different income brackets.
#
# Other than sponsoring tests, the State can also spend on areas that improve participation rates indirectly.
#
# The data also shows that income, K-12 spending and State & Local funding affect the participation rates for SAT. Although it is not possible for Oregon to increase the median household income directly, they could increase K-12 spending and state funding as they are spending lower than the averge state.
